# %% [markdown]
# <a href="https://colab.research.google.com/github/chenyu313/Colaboratory_note/blob/main/TransE2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#找到当前程序文件夹
# %cd /content/drive/MyDrive/TransE_code /transE-master2
# Out:
# /content/drive/MyDrive/TransE_code /transE-master2

# %%
#查看是否有GPU
import torch
print(torch.cuda.is_available())
# Out:
# True

# %%
#运行程序,训练transE
# %run tranE.py
# Out:
# 打开TransE
# TranE初始化
# entityVector初始化完成，数量是14951
# relationVectorList初始化完成，数量是1345
# 训练开始
# 第0次循环
# 170.30052234683546
# 写入关系
# 写入实体
# 第100次循环
# 17327.86918791998
# 写入关系
# 写入实体
# 第200次循环
# 17584.57432935213
# 写入关系
# 写入实体
# 第300次循环
# 18459.468195317968
# 写入关系
# 写入实体
# 第400次循环
# 18444.117137550435
# 写入关系
# 写入实体
# 第500次循环
# 18329.547196387026
# 写入关系
# 写入实体
# 第600次循环
# 18496.428859112482
# 写入关系
# 写入实体
# 第700次循环
# 18613.42758926257
# 写入关系
# 写入实体
# 第800次循环
# 18316.538417129963
# 写入关系
# 写入实体
# 第900次循环
# 18504.14528014434
# 写入关系
# 写入实体
# 第1000次循环
# 18636.547968806906
# 写入关系
# 写入实体
# 第1100次循环
# 18518.6580589941
# 写入关系
# 写入实体
# 第1200次循环
# 18375.80353154492
# 写入关系
# 写入实体
# 第1300次循环
# 18716.928122142846
# 写入关系
# 写入实体
# 第1400次循环
# 18801.12173909393
# 写入关系
# 写入实体
# 第1500次循环
# 18522.22387788231
# 写入关系
# 写入实体
# 第1600次循环
# 18422.95994954687
# 写入关系
# 写入实体
# 第1700次循环
# 18537.567082817113
# 写入关系
# 写入实体
# 第1800次循环
# 18554.71795104648
# 写入关系
# 写入实体
# 第1900次循环
# 18612.045159155532
# 写入关系
# 写入实体
# 第2000次循环
# ...

# %%
#训练test
# %run test.py
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
# 9994
# 11799
# 6808
# 12783
# 490
# 4380
# 3406
# 14545
# 3384
# 7202
# 7365
# 12225
# 8967
# 14140
# 7586
# 7668
# 6937
# 5699
# 7410
# 14946
# 8855
# 3136
# 5542
# 8882
# 1367
# 5066
# 8155
# 6909
# 7847
# 327
# 10487
# 2338
# 14833
# 3375
# 5809
# 11104
# 13610
# 9381
# 5831
# 9824
# 5899
# 2127
# 6964
# 4177
# 10567
# 3755
# 8532
# 13980
# 14502
# 13393
# 9225
# 9094
# 10770
# 6955
# 5071
# 9945
# 2147
# 7494
# 4322
# 3870
# 14452
# 12421
# 13250
# 13780
# 8040
# 9254
# 12254
# 8662
# 5154
# 8852
# 6649
# 8656
# 5923
# 10300
# 6804
# 10681
# 5649
# 12225
# 9128
# 4918
# 9026
# 10117
# 2804
# 13491
# 6459
# 5857
# 13898
# 10524
# 8604
# 3315
# 13538
# 272
# 10168
# 5852
# 10819
# 9814
# 290
# 3411
# 524
# 6839
# 12060
# 8862
# 10961
# 9738
# 868
# 4522
# 13064
# 11346
# 8171
# 8527
# 6485
# 6904
# 12045
# 12112
# 4116
# 978
# 5611
# 7786
# 789
# 10974
# 1339
# 10868
# 7071
# 3221
# 1885
# 10634
# 7398
# 2854
# 1911
# 9993
# 4446
# 13738
# 7041
# 14364
# ...
